# %%
import pandas as pd
from ECOv002_calval_tables import load_calval_table
from daylight_evapotranspiration import daylight_ET_from_instantaneous_LE

# %%
df = load_calval_table()
df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...  \
# 0     392.851840   307.021970  487.383423         118.916280  ...
# 1     640.118470   375.089300  106.825577         167.919460  ...
# 2     625.661700   284.686250         NaN         132.936340  ...
# 3     624.254330   251.414490  178.827545         141.132420  ...
# 4     511.082180   228.520170  154.791626         114.809410  ...
# ...          ...          ...         ...                ...  ...
# 1060   81.645230    15.282976         NaN          56.385185  ...
# 1061   65.469320    22.186659         NaN          40.509410  ...
# 1062  118.777240    55.343586         NaN          52.403820  ...
# 1063  126.490524    40.434025         NaN          57.769722  ...
# 1064  271.749480   119.763630  190.823303         122.092445  ...
#
#       insitu_LE_Wm2  insitu_H_Wm2  insitu_Rn_Wm2  insitu_G_Wm2  \
# 0        331.723100     69.623470      449.65123     14.831077
# 1        276.182074    228.756306      667.81900     38.638200
# 2        336.849808    169.322709      603.26000     26.775450
# 3        276.264202    231.754374      551.03800     13.319750
# 4        192.205091    155.974781      512.27100      6.896745
# ...             ...           ...            ...           ...
# 1060       9.395804    120.547093      171.34000    -13.347000
# 1061      46.867192    219.669478      177.33000     53.722333
# 1062      52.590710    113.437738      147.91000     45.282667
# 1063      91.493744    345.421536      338.90000      2.386667
# 1064     154.783501    518.549629      631.47000     95.436333
#
#       insitu_SWin_Wm2  insitu_Ta_C  insitu_RH  insitu_Rn_daylight_Wm2  \
# 0            596.8641     31.80107   0.636848              268.829847
# 1                 NaN     26.23260        NaN              346.382557
# 2                 NaN     30.26300        NaN              311.373843
# 3                 NaN     23.63330        NaN              298.014172
# 4                 NaN     24.33430        NaN              300.483101
# ...               ...          ...        ...                     ...
# 1060         354.4450      2.23884   0.507300              130.709188
# 1061         392.6050     16.94966   0.386400              189.792524
# 1062         385.0550     34.05052   0.079800              151.583691
# 1063         552.7300     10.91754   0.326400              291.834038
# 1064         966.0500     29.57192   0.255400              331.951225
#
#       insitu_LE_daylight_Wm2  insitu_ET_daylight_kg
# 0                 205.089552               3.521847
# 1                 152.046364               3.361398
# 2                 181.941076               4.018909
# 3                 153.111127               3.377459
# 4                 114.280419               2.519399
# ...                      ...                    ...
# 1060                6.649726               0.094448
# 1061               71.961900               1.284029
# 1062               77.678077               1.461298
# 1063               79.346005               1.500961
# 1064               95.853257               1.842696
#
# [1065 rows x 91 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'vegetation', 'climate', 'STICinst', 'BESSinst',
#        'MOD16inst', 'PTJPLSMinst', 'ETinst', 'ETinstUncertainty', 'PET', 'Rn',
#        'ESI', 'RH', 'Ta', 'LST', 'SM', 'NDVI', 'NDVI-UQ', 'albedo',
#        'albedo-UQ', 'LST_err', 'view_zenith', 'Rg', 'EmisWB', 'time_utc',
#        'solar_time', 'solar_hour', 'local_time', 'LE', 'LE_filt', 'LEcorr25',
#        'LEcorr50', 'LEcorr75', 'LEcorr_ann', 'H_filt', 'Hcorr25', 'Hcorr50',
#        'Hcorr75', 'Hcorr_ann', 'NETRAD_filt', 'G_filt', 'SM_surf', 'SM_rz',
#        'AirTempC', 'SW_IN', 'RH_percentage', 'ESIrn_STIC', 'ESIrn_PTJPLSM',
#        'ESIrn_MOD16', 'ESIrn_BESS', 'ESIrn_Unc_ECO', 'ESIrn_LEcorr50', 'JET',
#        'eco_time_utc', 'Site Name', 'Date-Time', 'Site ID', 'Name', 'Lat',
#        'Long', 'Elev', 'Clim', 'Veg', 'MAT', 'MAP', 'StartDate', 'EndDate',
#        'LE_count', 'closure_ratio', 'geometry', 'elevation_m', 'time_UTC',
#        'ST_K', 'ST_C', 'Ta_C', 'SWin_Wm2', 'emissivity', 'orbit', 'scene',
#        'tile', 'insitu_LE_Wm2', 'insitu_H_Wm2', 'insitu_Rn_Wm2',
#        'insitu_G_Wm2', 'insitu_SWin_Wm2', 'insitu_Ta_C', 'insitu_RH',
#        'insitu_Rn_daylight_Wm2', 'insitu_LE_daylight_Wm2',
#        'insitu_ET_daylight_kg'],
#       dtype='object')

# %%
daylight_results = daylight_ET_from_instantaneous_LE(
    LE_instantaneous_Wm2=df.LEcorr50,
    Rn_instantaneous_Wm2=df.NETRAD_filt,
    G_instantaneous_Wm2=df.G_filt,
    time_UTC=df.time_UTC,
    geometry=df.geometry
)

daylight_results = {f"insitu_{key}": value for key, value in daylight_results.items()}

daylight_results
# Out:
# {'insitu_Rn_daylight_Wm2': 0       268.829847
#  1       346.382557
#  2       311.373843
#  3       298.014172
#  4       300.483101
#             ...
#  1060    130.709188
#  1061    189.792524
#  1062    151.583691
#  1063    291.834038
#  1064    331.951225
#  Name: NETRAD_filt, Length: 1065, dtype: float64,
#  'insitu_LE_daylight_Wm2': 0       205.089552
#  1       152.046364
#  2       181.941076
#  3       153.111127
#  4       114.280419
#             ...
#  1060      6.649726
#  1061     71.961900
#  1062     77.678077
#  1063     79.346005
#  1064     95.853257
#  Name: NETRAD_filt, Length: 1065, dtype: float64,
#  'insitu_ET_daylight_kg': array([3.52184682, 3.36139787, 4.0189093 , ..., 1.46129772, 1.5009611 ,
#         1.84269551], shape=(1065,))}

# %%
def upscale_to_daylight(df: pd.DataFrame, prefix: str = "insitu_") -> pd.DataFrame:
    daylight_results = daylight_ET_from_instantaneous_LE(
        LE_instantaneous_Wm2=df.LEcorr50,
        Rn_instantaneous_Wm2=df.NETRAD_filt,
        G_instantaneous_Wm2=df.G_filt,
        time_UTC=df.time_UTC,
        geometry=df.geometry
    )
    
    daylight_results_prefixed = {f"{prefix}{k}": v for k, v in daylight_results.items()}
    
    for key, value in daylight_results_prefixed.items():
        df[key] = value

    return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 def upscale_to_daylight(df: pd.DataFrame, prefix: str = "insitu_") -> pd.DataFrame:
#       2     daylight_results = daylight_ET_from_instantaneous_LE(
#       3         LE_instantaneous_Wm2=df.LEcorr50,
#       4         Rn_instantaneous_Wm2=df.NETRAD_filt,
#    (...)
#       7         geometry=df.geometry
#       8     )
#      10     daylight_results_prefixed = {f"{prefix}{k}": v for k, v in daylight_results.items()}
#
# NameError: name 'pd' is not defined
